# %% [markdown]
# # Controller Testing with Sarsa

# %%
from velora import RLController
import torch

from velora.agent import Sarsa, ExpectedSarsa, QLearning
from velora.env.gym import GymEnvHandler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
RUN_NAME = "test2"

# %%
sarsa = RLController(
    config_filepath="config/sarsa.yaml",
    env_type=GymEnvHandler,
    agent_type=Sarsa,
    device=device,
)

q_learning = RLController(
    config_filepath="config/sarsa.yaml",
    env_type=GymEnvHandler,
    agent_type=QLearning,
    device=device,
)

expected_sarsa = RLController(
    config_filepath="config/sarsa.yaml",
    env_type=GymEnvHandler,
    agent_type=ExpectedSarsa,
    device=device,
)
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: achronus (achronus-uk). Use `wandb login --relogin` to force relogin

# %%
sarsa.train(RUN_NAME)
# Out:
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>c:\Projects\portfolio\velora\examples\wandb\run-20241208_122251-0zfff3ie</code>
# Syncing run <strong><a href='https://wandb.ai/achronus-uk/RLController-CliffWalking-v0/runs/0zfff3ie' target="_blank">test2</a></strong> to <a href='https://wandb.ai/achronus-uk/RLController-CliffWalking-v0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/achronus-uk/RLController-CliffWalking-v0' target="_blank">https://wandb.ai/achronus-uk/RLController-CliffWalking-v0</a>
#  View run at <a href='https://wandb.ai/achronus-uk/RLController-CliffWalking-v0/runs/0zfff3ie' target="_blank">https://wandb.ai/achronus-uk/RLController-CliffWalking-v0/runs/0zfff3ie</a>
# Episode 100/1000 | Episode Batch - Avg Score: -832.93, Avg Loss: 3.33, Terminal Reached: 60.0%
# Episode 200/1000 | Episode Batch - Avg Score: -147.58, Avg Loss: 1.04, Terminal Reached: 97.0%
# Episode 300/1000 | Episode Batch - Avg Score: -119.69, Avg Loss: 0.94, Terminal Reached: 100.0%
# Episode 400/1000 | Episode Batch - Avg Score: -99.75, Avg Loss: 0.93, Terminal Reached: 100.0%
# Episode 500/1000 | Episode Batch - Avg Score: -73.03, Avg Loss: 0.78, Terminal Reached: 100.0%
# Episode 600/1000 | Episode Batch - Avg Score: -65.64, Avg Loss: 0.76, Terminal Reached: 100.0%
# Episode 700/1000 | Episode Batch - Avg Score: -60.89, Avg Loss: 0.67, Terminal Reached: 100.0%
# Episode 800/1000 | Episode Batch - Avg Score: -58.18, Avg Loss: 0.68, Terminal Reached: 100.0%
# Episode 900/1000 | Episode Batch - Avg Score: -54.14, Avg Loss: 0.59, Terminal Reached: 100.0%
# Episode 1000/1000 | Episode Batch - Avg Score: -41.07, Avg Loss: 0.56, Terminal Reached: 100.0%
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▂▁▁▂▁▁▂▂▁▁▂▂▁▂▁▂▁▁▁▂▁▁▁▁▂▁▁▁</td></tr><tr><td>score</td><td>▇▇▁▆▇▅▇▇▇▆▇▇▆▇▆▅▇█▇█████▅███████▆▆█▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.3883</td></tr><tr><td>score</td><td>-40</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test2</strong> at: <a href='https://wandb.ai/achronus-uk/RLController-CliffWalking-v0/runs/0zfff3ie' target="_blank">https://wandb.ai/achronus-uk/RLController-CliffWalking-v0/runs/0zfff3ie</a><br/> View project at: <a href='https://wandb.ai/achronus-uk/RLController-CliffWalking-v0' target="_blank">https://wandb.ai/achronus-uk/RLController-CliffWalking-v0</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20241208_122251-0zfff3ie\logs</code>

# %%
sarsa.plot_vf()
